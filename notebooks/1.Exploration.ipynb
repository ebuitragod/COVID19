# %%
import pandas as pd

# %% [markdown]
# # GET DATA

# %%
df = pd.read_csv("../data/raw/COVID 19 Containment measures data.csv")
df.shape
# Out:
# (1036, 16)

# %% [markdown]
# # EXPLORATION

# %%
df["Country"].value_counts(ascending=True).plot(kind='barh', figsize=(20,20));

# %%
df["Date Start"] = pd.to_datetime(df["Date Start"])

# %%
df["Date Start"].describe()
# Out:
# count                    1008
# unique                     81
# top       2020-03-16 00:00:00
# freq                       98
# first     2019-12-18 00:00:00
# last      2021-12-30 00:00:00
# Name: Date Start, dtype: object
